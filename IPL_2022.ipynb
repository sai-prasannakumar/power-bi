# %%
import pandas as pd
import numpy as np
import datetime
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_html("https://stats.espncricinfo.com/ci/engine/records/team/match_results.html?id=14452;type=tournament")

# %%
res = df[0]

# %%
res
# Out:
#           Team 1        Team 2        Winner     Margin        Ground  \
# 0    Super Kings           KKR           KKR  6 wickets      Wankhede
# 1       Capitals        Mumbai      Capitals  4 wickets     Brabourne
# 2   Punjab Kings           RCB  Punjab Kings  5 wickets      DY Patil
# 3         Titans  Super Giants        Titans  5 wickets      Wankhede
# 4      Sunrisers        Royals        Royals    61 runs          Pune
# ..           ...           ...           ...        ...           ...
# 69     Sunrisers  Punjab Kings  Punjab Kings  5 wickets      Wankhede
# 70        Titans        Royals        Titans  7 wickets  Eden Gardens
# 71  Super Giants           RCB           RCB    14 runs  Eden Gardens
# 72        Royals           RCB        Royals  7 wickets     Ahmedabad
# 73        Titans        Royals        Titans  7 wickets     Ahmedabad
#
#       Match Date Scorecard
# 0   Mar 26, 2022       T20
# 1   Mar 27, 2022       T20
# 2   Mar 27, 2022       T20
# ...

# %%
res['Margin'] = res['Margin'].apply(str)
res['Win_Method'] = np.where(res['Margin'].str.endswith('ns'),'chasing','defending')

# %%
res
# Out:
#           Team 1        Team 2        Winner     Margin        Ground  \
# 0    Super Kings           KKR           KKR  6 wickets      Wankhede
# 1       Capitals        Mumbai      Capitals  4 wickets     Brabourne
# 2   Punjab Kings           RCB  Punjab Kings  5 wickets      DY Patil
# 3         Titans  Super Giants        Titans  5 wickets      Wankhede
# 4      Sunrisers        Royals        Royals    61 runs          Pune
# ..           ...           ...           ...        ...           ...
# 69     Sunrisers  Punjab Kings  Punjab Kings  5 wickets      Wankhede
# 70        Titans        Royals        Titans  7 wickets  Eden Gardens
# 71  Super Giants           RCB           RCB    14 runs  Eden Gardens
# 72        Royals           RCB        Royals  7 wickets     Ahmedabad
# 73        Titans        Royals        Titans  7 wickets     Ahmedabad
#
#       Match Date Scorecard Win_Method
# 0   Mar 26, 2022       T20  defending
# 1   Mar 27, 2022       T20  defending
# ...

# %%
res.columns
# Out:
# Index(['Team 1', 'Team 2', 'Winner', 'Margin', 'Ground', 'Match Date',
#        'Scorecard', 'Win_Method'],
#       dtype='object')

# %%
results = res[['Team 1', 'Team 2', 'Winner','Win_Method', 'Margin', 'Ground']]

# %%
results['Team 2'].unique()
# Out:
# array(['KKR', 'Mumbai', 'RCB', 'Super Giants', 'Royals', 'Super Kings',
#        'Punjab Kings', 'Capitals', 'Titans', 'Sunrisers'], dtype=object)

# %%
results.to_csv(r'D:\Data Science\project cricket\results.csv')
